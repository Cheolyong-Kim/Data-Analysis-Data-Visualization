# %% [markdown]
# # 시각화

# %% [markdown]
# ##### 1.초기설정

# %%
import matplotlib.pyplot as plt
#import matplotlib
#matplotlib.rcParams['font.family']='Malgun Gothic' #폰트 지정해서 사용할 수 있게 해줌(한글 폰트 지정)
#matplotlib.rcParams['axes.unicode_minus']=False #맑은 고딕으로 폰트 지정하면 -가 깨져나와서 -는 폰트 지정 안함3#

# %%
x=[1,2,3]
y=[2,4,8]
y1=[1,3,7]

plt.plot(x,y) #맷플롯에 data 전달
plt.plot(x,y1)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np

x_1=range(100)
x_2=range(100)
y_1=[np.cos(i) for i in x_1]
y_2=[np.sin(i) for i in x_2]

plt.plot(x_1,y_1)
plt.plot(x_2,y_2)

# %%
fig,ax=plt.subplots()
x_1=range(100)
y_1=[np.cos(i) for i in x_1]
ax.plot(x_1,y_1)
ax.set(title="cos_g",xlabel="X",ylabel="Y")
plt.show()

# %%
x=[1,2,3]
y=[-4,-8,-6]
plt.plot(x,y)
plt.title("꺾은 선 그래프")
# Out:
# Text(0.5, 1.0, '꺾은 선 그래프')

# %%
import matplotlib.font_manager
[f.name for f in matplotlib.font_manager.fontManager.ttflist] #폰트 이름 검색
# Out:
# ['STIXSizeFiveSym',
#  'cmtt10',
#  'DejaVu Serif',
#  'STIXNonUnicode',
#  'STIXSizeThreeSym',
#  'STIXGeneral',
#  'DejaVu Sans Mono',
#  'cmmi10',
#  'STIXSizeTwoSym',
#  'STIXNonUnicode',
#  'STIXGeneral',
#  'DejaVu Serif',
#  'cmex10',
#  'cmr10',
#  'DejaVu Sans Display',
#  'DejaVu Sans Mono',
#  'DejaVu Serif Display',
#  'DejaVu Sans Mono',
#  'cmss10',
#  'DejaVu Serif',
#  'STIXNonUnicode',
#  'STIXSizeThreeSym',
#  'DejaVu Sans',
#  'DejaVu Sans',
#  'STIXGeneral',
#  'DejaVu Sans',
#  'cmb10',
#  'DejaVu Sans Mono',
#  'STIXNonUnicode',
#  'cmsy10',
#  'STIXSizeFourSym',
#  'STIXSizeOneSym',
#  'STIXSizeTwoSym',
#  'DejaVu Sans',
#  'DejaVu Serif',
#  'STIXSizeFourSym',
#  'STIXGeneral',
#  'STIXSizeOneSym',
#  'SimSun-ExtB',
#  'Adobe Heiti Std',
#  'Arial',
#  'MS Gothic',
#  'AR HERMANN',
#  'AR BLANCA',
#  'Minion Pro',
#  'Cambria',
#  'Letter Gothic Std',
#  'Adobe Caslon Pro',
#  'Verdana',
#  'Kozuka Mincho Pr6N',
#  'Minion Pro',
#  'Minion Pro',
#  'Segoe UI',
#  'Comic Sans MS',
#  'Candara',
#  'Charlemagne Std',
#  'AR DARLING',
#  'Lucida Sans Unicode',
#  'YDIYGO130-KSCpc-EUC-H',
#  'Adobe Hebrew',
#  'Tekton Pro',
#  'Adobe Hebrew',
#  'Courier New',
#  'Mongolian Baiti',
#  'Minion Pro',
#  'Microsoft PhagsPa',
#  'Chaparral Pro',
#  'Candara',
#  'Ebrima',
#  'Tekton Pro',
#  'Franklin Gothic Medium',
#  'Corbel',
#  'Nirmala UI',
#  'Cambria',
#  'Gulim',
#  'Adobe Heiti Std',
#  'Kozuka Gothic Pr6N',
#  'Myriad Pro',
#  'Sitka Small',
#  'Consolas',
#  'Letter Gothic Std',
#  'Georgia',
#  'Gulim',
#  'OCR A Std',
#  'MingLiU-ExtB',
#  'Adobe Caslon Pro',
#  'Adobe Hebrew',
#  'Tekton Pro',
#  'Yu Gothic',
#  'Candara',
#  'Microsoft YaHei',
#  'Malgun Gothic',
#  'AR DELANEY',
#  'Adobe Hebrew',
#  'SimSun',
#  'Segoe UI',
#  'Times New Roman',
#  'Microsoft YaHei',
#  'Minion Pro',
#  'AR DELANEY',
#  'Orator Std',
#  'Adobe Caslon Pro',
#  'Yu Gothic',
#  'Comic Sans MS',
#  'Chaparral Pro',
#  'Palatino Linotype',
#  'Trajan Pro',
#  'Mesquite Std',
#  'Franklin Gothic Medium',
#  'DAUL-EQN2',
#  'Lithos Pro',
#  'Webdings',
#  'Minion Pro',
#  'NanumGothic',
#  'Segoe UI',
#  'Gadugi',
#  'Minion Pro',
#  'Candara',
#  'Corbel',
#  'Kozuka Mincho Pro',
#  'Georgia',
#  'Cooper Std',
#  'Segoe UI',
#  'Yu Gothic',
#  'Corbel',
#  'Lucida Console',
#  'Segoe UI',
#  'Tekton Pro',
#  'SimSun',
#  'Malgun Gothic',
#  'Microsoft PhagsPa',
#  'Hobo Std',
#  'Ink Free',
#  'Calibri',
#  'Microsoft Sans Serif',
#  'Arial',
#  'Constantia',
#  'HCR Batang ExtB',
#  'Microsoft Tai Le',
#  'Letter Gothic Std',
#  'NewJumja',
#  'Adobe Caslon Pro',
#  'Kozuka Gothic Pro',
#  'Myriad Pro',
#  'Trebuchet MS',
#  'Microsoft JhengHei',
#  'Adobe Caslon Pro',
#  'Times New Roman',
#  'Constantia',
#  'Microsoft New Tai Lue',
#  'MS Gothic',
#  'Leelawadee UI',
#  'Letter Gothic Std',
#  'Candara',
#  'Verdana',
#  'UNAVAILABLE',
#  'Microsoft Yi Baiti',
#  'Adobe Garamond Pro',
#  'Kozuka Gothic Pr6N',
#  'Segoe UI Emoji',
#  'Segoe Script',
#  'Myriad Pro',
#  'Segoe UI',
#  'Adobe Arabic',
#  'Tahoma',
#  'AR HERMANN',
#  'UNAVAILABLE',
#  'Myriad Pro',
#  'HCR Batang ExtB',
#  'Batang',
#  'HCR Dotum',
#  'Microsoft Tai Le',
#  'HoloLens MDL2 Assets',
#  'Verdana',
#  'Microsoft Tai Le',
#  'Marlett',
#  'Adobe Song Std',
#  'Tahoma',
#  'Sitka Small',
#  'Wingdings',
#  'MV Boli',
#  'HCR Dotum Ext',
#  'Kozuka Mincho Pro',
#  'Segoe UI Symbol',
#  'AR DESTINE',
#  'MV Boli',
#  'Times New Roman',
#  'Arial',
#  'Leelawadee UI',
#  'Consolas',
#  'Myriad Pro',
#  'YDIYGO120-KSCpc-EUC-H',
#  'Georgia',
#  'Trajan Pro',
#  'Palatino Linotype',
#  'Adobe Arabic',
#  'Microsoft YaHei',
#  'Myriad Pro',
#  'Candara',
#  'Nueva Std',
#  'Poplar Std',
#  'HyhwpEQ',
#  'Adobe Caslon Pro',
#  'Adobe Garamond Pro',
#  'Hancom Gothic',
#  'Giddyup Std',
#  'Symbol',
#  'Palatino Linotype',
#  'Blackoak Std',
#  'HancomEQN',
#  'Nueva Std',
#  'Adobe Garamond Pro',
#  'Brush Script Std',
#  'Minion Pro',
#  'Kozuka Mincho Pr6N',
#  'Microsoft JhengHei',
#  'Segoe UI Symbol',
#  'Nueva Std',
#  'Kozuka Gothic Pr6N',
#  'YDIYGO160-KSCpc-EUC-H',
#  'Adobe Fan Heiti Std',
#  'Kozuka Mincho Pr6N',
#  'Hancom Gothic',
#  'Adobe Myungjo Std',
#  'AR CENA',
#  'Arial',
#  'HCR Dotum',
#  'Comic Sans MS',
#  'Kozuka Gothic Pr6N',
#  'HCR Batang ExtB',
#  'Segoe UI',
#  'Segoe Script',
#  'UNAVAILABLE',
#  'Consolas',
#  'Rosewood Std',
#  'Myriad Pro',
#  'HancomEQN',
#  'Cooper Std',
#  'Franklin Gothic Medium',
#  'Segoe UI',
#  'UNAVAILABLE',
#  'Kozuka Gothic Pr6N',
#  'Tahoma',
#  'Adobe Kaiti Std',
#  'Candara',
#  'Minion Pro',
#  'Segoe UI',
#  'Adobe Garamond Pro',
#  'Kozuka Mincho Pr6N',
#  'Poplar Std',
#  'Corbel',
#  'Kozuka Gothic Pro',
#  'Corbel',
#  'AR JULIAN',
#  'Kozuka Gothic Pr6N',
#  'Trajan Pro',
#  'Myriad Pro',
#  'Microsoft JhengHei',
#  'Kozuka Gothic Pr6N',
#  'Myriad Pro',
#  'Minion Pro',
#  'Wingdings',
#  'Kozuka Mincho Pro',
#  'Tekton Pro',
#  'Microsoft YaHei',
#  'Chaparral Pro',
#  'NanumGothic',
#  'Adobe Kaiti Std',
#  'Calibri',
#  'Adobe Caslon Pro',
#  'Calibri',
#  'HCR Batang',
#  'Myriad Pro',
#  'Chaparral Pro',
#  'Segoe UI Historic',
#  'Adobe Hebrew',
#  'Kozuka Mincho Pro',
#  'Adobe Caslon Pro',
#  'Corbel',
#  'Bahnschrift',
#  'Microsoft Yi Baiti',
#  'Sitka Small',
#  'YDIYGO140-KSCpc-EUC-H',
#  'Consolas',
#  'Microsoft JhengHei',
#  'Myanmar Text',
#  'Ebrima',
#  'Adobe Song Std',
#  'Adobe Fan Heiti Std',
#  'Malgun Gothic',
#  'Kozuka Gothic Pro',
#  'Kozuka Gothic Pro',
#  'Segoe MDL2 Assets',
#  'Lithos Pro',
#  'Myriad Pro',
#  'Nueva Std',
#  'Kozuka Gothic Pro',
#  'Georgia',
#  'Calibri',
#  'Orator Std',
#  'Webdings',
#  'Cambria',
#  'Palatino Linotype',
#  'Chaparral Pro',
#  'Adobe Gothic Std',
#  'AR BLANCA',
#  'Chaparral Pro',
#  'Gong Gothic',
#  'Verdana',
#  'Segoe Print',
#  'Segoe UI',
#  'Hancom Gothic',
#  'Microsoft Tai Le',
#  'Constantia',
#  'Adobe Arabic',
#  'Consolas',
#  'Minion Pro',
#  'V3Detect',
#  'Myriad Pro',
#  'Trebuchet MS',
#  'Segoe UI',
#  'AR BERKLEY',
#  'Segoe Print',
#  'Corbel',
#  'AR JULIAN',
#  'HCR Batang ExtB',
#  'Rosewood Std',
#  'Verdana',
#  'Adobe Caslon Pro',
#  'Trebuchet MS',
#  'Nueva Std',
#  'Adobe Arabic',
#  'Segoe UI',
#  'Times New Roman',
#  'Consolas',
#  'Minion Pro',
#  'Minion Pro',
#  'Adobe Ming Std',
#  'Constantia',
#  'Corbel',
#  'Segoe MDL2 Assets',
#  'Segoe UI Historic',
#  'Kozuka Gothic Pr6N',
#  'Mongolian Baiti',
#  'Sitka Small',
#  'Kozuka Mincho Pr6N',
#  'Kozuka Mincho Pr6N',
#  'Kozuka Gothic Pr6N',
#  'Times New Roman',
#  'Adobe Caslon Pro',
#  'Kozuka Mincho Pro',
#  'Prestige Elite Std',
#  'Trebuchet MS',
#  'Courier New',
#  'Kozuka Mincho Pr6N',
#  'Times New Roman',
#  'Comic Sans MS',
#  'AR BONNIE',
#  'Microsoft PhagsPa',
#  'Calibri',
#  'Georgia',
#  'Myanmar Text',
#  'Adobe Hebrew',
#  'Javanese Text',
#  'Sitka Small',
#  'Yu Gothic',
#  'Adobe Arabic',
#  'Gong Gothic',
#  'Kozuka Gothic Pro',
#  'Georgia',
#  'Adobe Myungjo Std',
#  'Adobe Fangsong Std',
#  'Constantia',
#  'Yu Gothic',
#  'AR BERKLEY',
#  'Lithos Pro',
#  'Segoe UI',
#  'Verdana',
#  'Orator Std',
#  'Verdana',
#  'Segoe UI',
#  'Courier New',
#  'Lithos Pro',
#  'OCR A Std',
#  'AR DECODE',
#  'Trebuchet MS',
#  'Comic Sans MS',
#  'Kozuka Mincho Pro',
#  'Segoe Script',
#  'Segoe UI',
#  'Corbel',
#  'Adobe Garamond Pro',
#  'Microsoft New Tai Lue',
#  'Candara',
#  'Symbol',
#  'V3Detect',
#  'Comic Sans MS',
#  'Microsoft Sans Serif',
#  'Kozuka Mincho Pr6N',
#  'Adobe Caslon Pro',
#  'Trebuchet MS',
#  'SimSun-ExtB',
#  'Myriad Pro',
#  'Microsoft PhagsPa',
#  'Consolas',
#  'Charlemagne Std',
#  'Courier New',
#  'Mesquite Std',
#  'Calibri',
#  'Adobe Hebrew',
#  'Segoe UI',
#  'Trebuchet MS',
#  'Candara',
#  'Letter Gothic Std',
#  'Consolas',
#  'AR CENA',
#  'Ebrima',
#  'Comic Sans MS',
#  'Sylfaen',
#  'Cambria',
#  'Constantia',
#  'Kozuka Mincho Pro',
#  'Courier New',
#  'Myriad Pro',
#  'HCR Batang',
#  'Cambria',
#  'Adobe Garamond Pro',
#  'HCR Dotum Ext',
#  'Orator Std',
#  'Minion Pro',
#  'Kozuka Gothic Pro',
#  'Trebuchet MS',
#  'Giddyup Std',
#  'Georgia',
#  'YDIYGO150-KSCpc-EUC-H',
#  'AR ESSENCE',
#  'AR BONNIE',
#  'HCR Batang Ext',
#  'Cooper Std',
#  'HCR Batang',
#  'AR CARTER',
#  'Segoe UI',
#  'Georgia',
#  'Verdana',
#  'Microsoft New Tai Lue',
#  'Leelawadee UI',
#  'Javanese Text',
#  'MingLiU-ExtB',
#  'Sitka Small',
#  'Calibri',
#  'HCR Dotum',
#  'Kozuka Gothic Pro',
#  'Kozuka Gothic Pro',
#  'AR DECODE',
#  'Palatino Linotype',
#  'Leelawadee UI',
#  'AR CHRISTY',
#  'Leelawadee UI',
#  'Arial',
#  'Kozuka Gothic Pro',
#  'Tekton Pro',
#  'Sylfaen',
#  'Blackoak Std',
#  'YDIYGO110-KSCpc-EUC-H',
#  'Batang',
#  'Adobe Ming Std',
#  'Impact',
#  'Kozuka Mincho Pr6N',
#  'Malgun Gothic',
#  'Myriad Pro',
#  'Nirmala UI',
#  'Corbel',
#  'Adobe Arabic',
#  'Nirmala UI',
#  'Nueva Std',
#  'AR CHRISTY',
#  'Adobe Fangsong Std',
#  'Ink Free',
#  'Microsoft YaHei',
#  'Letter Gothic Std',
#  'Calibri',
#  'AR DARLING',
#  'Nirmala UI',
#  'Segoe UI',
#  'Tahoma',
#  'HCR Batang',
#  'UNAVAILABLE',
#  'Microsoft Himalaya',
#  'Nirmala UI',
#  'Segoe UI',
#  'Cambria',
#  'Cambria',
#  'Letter Gothic Std',
#  'Minion Pro',
#  'Hancom Gothic',
#  'Constantia',
#  'Lucida Console',
#  'Nueva Std',
#  'Kozuka Mincho Pro',
#  'Arial',
#  'Kozuka Mincho Pro',
#  'Gong Gothic',
#  'Impact',
#  'Gadugi',
#  'Adobe Arabic',
#  'Segoe UI',
#  'Constantia',
#  'Myriad Pro',
#  'Courier New',
#  'Hobo Std',
#  'Minion Pro',
#  'Chaparral Pro',
#  'Segoe UI',
#  'Gabriola',
#  'Letter Gothic Std',
#  'Times New Roman',
#  'Arial',
#  'Microsoft Himalaya',
#  'Adobe Caslon Pro',
#  'Kozuka Mincho Pr6N',
#  'Minion Pro',
#  'Stencil Std',
#  'Tekton Pro',
#  'Lucida Sans Unicode',
#  'Gadugi',
#  'Myanmar Text',
#  'Arial',
#  'Birch Std',
#  'Calibri',
#  'Candara',
#  'Kozuka Mincho Pro',
#  'Brush Script Std',
#  'Minion Pro',
#  'AR DESTINE',
#  'HoloLens MDL2 Assets',
#  'Yu Gothic',
#  'Malgun Gothic',
#  'Haan Wing2',
#  'Gabriola',
#  'Haan Wing2',
#  'Myriad Pro',
#  'Kozuka Mincho Pro',
#  'Candara',
#  'HyhwpEQ',
#  'AR CARTER',
#  'Segoe UI',
#  'Calibri',
#  'Segoe Print',
#  'Stencil Std',
#  'Minion Pro',
#  'Myriad Pro',
#  'Sitka Small',
#  'Palatino Linotype',
#  'Tekton Pro',
#  'Minion Pro',
#  'Segoe Script',
#  'Palatino Linotype',
#  'Kozuka Mincho Pro',
#  'Kozuka Gothic Pr6N',
#  'Myriad Pro',
#  'Prestige Elite Std',
#  'Yu Gothic',
#  'Leelawadee UI',
#  'DAUL-EQN2',
#  'Myanmar Text',
#  'HCR Dotum',
#  'Palatino Linotype',
#  'Microsoft New Tai Lue',
#  'KoreanDDDDR',
#  'Adobe Garamond Pro',
#  'NewJumja',
#  'Comic Sans MS',
#  'Arial',
#  'Kozuka Gothic Pro',
#  'Kozuka Mincho Pr6N',
#  'Kozuka Gothic Pr6N',
#  'Adobe Garamond Pro',
#  'Calibri',
#  'Corbel',
#  'Nueva Std',
#  'Microsoft JhengHei',
#  'UNAVAILABLE',
#  'Bahnschrift',
#  'Birch Std',
#  'Microsoft YaHei',
#  'Times New Roman',
#  'Sitka Small',
#  'Yu Gothic',
#  'Microsoft JhengHei',
#  'Segoe UI',
#  'Gadugi',
#  'Arial',
#  'Cambria',
#  'Segoe Print',
#  'AR ESSENCE',
#  'HCR Batang Ext',
#  'Kozuka Mincho Pr6N',
#  'Kozuka Gothic Pr6N',
#  'Nirmala UI',
#  'Adobe Hebrew',
#  'Segoe UI',
#  'Courier New',
#  'Adobe Arabic',
#  'Calibri',
#  'Corbel',
#  'Adobe Gothic Std',
#  'Candara',
#  'Chaparral Pro',
#  'Ebrima',
#  'Courier New',
#  'Franklin Gothic Medium',
#  'Malgun Gothic',
#  'Myriad Pro',
#  'Segoe UI Emoji',
#  'Cooper Std',
#  'Kozuka Gothic Pro',
#  'Trajan Pro']

# %%
x=[1,2,3]
y=[-4,-8,-6]
plt.plot(x,y)
plt.title("꺾은 선 그래프",fontdict={'family':'Malgun Gothic', 'size':'25'}) #fontdict으로 폰트 설정 가능
plt.xlabel('가로축',color="red",fontdict={'family':'Malgun Gothic', 'size':'25'},loc='left') 
#color로 폰트 색 지정 가능
#loc로 위치 조정 가능 (가로: center,left,roght / 세로: center,top,bottom)
plt.ylabel('세로축',color="green",fontdict={'family':'Malgun Gothic', 'size':'25'},loc='bottom')
# plt.xticks([1,2,3,6])
# plt.yticks([4,6,8,10])
plt.show()

# %%
fig=plt.figure()
fig.set_size_inches(10,10)

x_1=range(100)
x_2=range(100)
y_1=[np.cos(i) for i in x_1]
y_2=[np.sin(i) for i in x_2]

ax_1=fig.add_subplot(1,2,1)
ax_2=fig.add_subplot(1,2,2)
ax_1.plot(x_1,y_1)
ax_2.plot(x_2,y_2)
plt.show()

# %%
fig,ax=plt.subplots(nrows=2,ncols=2)
ax
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
fig,ax=plt.subplots(2,2) #add_subplot대신 미리 서브플롯의 칸을 지정해서 만들어 놓을 수 있음
x=np.linspace(-1,1,100)
y1=np.sin(x)
y2=np.cos(x)
y3=np.tan(x)
y4=np.exp(x)

ax[0,0].plot(x,y1) #만들어 놓은 서브플롯들은 좌표로 접근가능(ndarray이기 때문)
ax[0,1].plot(x,y2)
ax[1,0].plot(x,y3)
ax[1,1].plot(x,y4)

plt.show()

# %%
ax1=plt.subplot(321)
plt.plot(x,y1)
ax2=plt.subplot(322)
plt.plot(x,y2)
ax3=plt.subplot(312)
plt.plot(x,y3)
ax4=plt.subplot(325)
plt.plot(x,y4)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(x,y1,label='sin')
plt.plot(x,y2,label='cos')
plt.legend(loc='upper left')
#(좌측상단=upper left / 좌측하단=lower left, 우측 동일)
plt.legend(loc=(0,0)) #좌표 위치도 설정 가능
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(x,y1,label='sin',color="green")
plt.plot(x,y2,label='cos',c="r")
plt.show()

# %%
plt.plot(x,y1,label='sin',color="green",linestyle='dashed')
plt.plot(x,y2,label='cos',c="r",ls='dotted')
plt.title('all_p')
plt.show()

# %%
plt.plot(x,y1,c='r',ls='dashed',label='sin')
plt.plot(x,y2,c='b',ls='dotted',label='cos')
plt.plot(x,y3,c='g',ls='solid',label='tan')
plt.plot(x,y4,c='c',label='exp',linewidth=5)
plt.legend(loc='best',shadow=True)
plt.show()

# %%
#marker로 데이터가 있는 위치만 표시 가능
plt.plot(x,y1,c='r',ls='dashed',label='sin',marker='o')
plt.plot(x,y2,c='b',ls='dotted',label='cos',marker='*')
plt.plot(x,y3,c='g',ls='solid',label='tan')
plt.plot(x,y4,c='c',ls='None',label='exp',linewidth=5,marker='o')
plt.legend(loc='best',shadow=True)
plt.show()

# %%
x=[1,2,3]
y=[1,5,15]
x1=[1,3]
y1=[1,15]
plt.plot(x,y,marker='v')
plt.plot(x1,y1,marker='v')
